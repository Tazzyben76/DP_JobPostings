# %%
import pandas as pd
import re
import psycopg2
from psycopg2.extras import execute_values

# --------------------------------------
# 1. READ CSV + CLEAN EXTRA SPACES
# --------------------------------------

def clean_spaces(val):
    """Remove duplicate/multiple spaces in any cell."""
    if pd.isna(val):
        return val
    return re.sub(r"\s+", " ", str(val)).strip()

csv_path = "DataEngineer_Cleaned.csv"   # <--- your CSV file path
df = pd.read_csv(csv_path, dtype=str).applymap(clean_spaces)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18200\1610345846.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = pd.read_csv(csv_path, dtype=str).applymap(clean_spaces)

# %%
# --------------------------------------
# 2. DATABASE CONNECTION
# --------------------------------------

conn = psycopg2.connect(
    host="jde08-ip-p2-angbj1976-c47c.c.aivencloud.com",
    dbname="Interim_Project_DB",
    user="********",
    password="********",
    port=15241
)

cur = conn.cursor()

# %%
# --------------------------------------
# 3. VERIFY COUNTRIES IN dim_countries
# --------------------------------------

def get_existing_countries():
    cur.execute("SELECT country_code FROM dim_countries;")
    return {row[0]: row[0] for row in cur.fetchall()}  # country_name → code

existing_countries = get_existing_countries()

unique_countries = df["Country"].dropna().unique()

# Country code mapping (you can extend this)
country_code_mapping = {
    "US": "US",
    "SG": "SG",
    "MY": "MY",
    "UK": "UK"
}


# Insert missing countries
#countries_to_insert = []
#for country in unique_countries:
#    if country not in existing_countries:
#        if country in country_code_mapping:
#            countries_to_insert.append((country_code_mapping[country], country))

#if countries_to_insert:
#    insert_sql = """
#     INSERT INTO dim_countries (country_code, country_name)
#     VALUES %s
#     ON CONFLICT (country_code) DO NOTHING;
#    """
#    execute_values(cur, insert_sql, countries_to_insert)
#    conn.commit()

# Refresh country list
#existing_countries = get_existing_countries()

# %%
# --------------------------------------
# 4. INSERT COMPANIES INTO dim_companies
# --------------------------------------

def clean_company_name(name):
 #   if not isinstance(name, str):
 #       return name
    
    x = name.strip().lower()
  #  print('z',x)
    if "collinwood" in x:
        print('y',x)
    # Remove extra punctuation
    x = re.sub(r"[^a-z0-9\s]", " ", x)

    # Collapse multiple spaces
    x = " ".join(x.split())
    # Optional: remove trailing words like "pte ltd", "ltd", "solutions" if used in lookup rules
    remove_terms = [
        r"\bpte ltd\b",
        r"\bltd\b",
        r"\bprivate limited\b",
        r"\bplc\b",
        r"\bllc\b", 
        r"\binc\b", 
        r"\bltd\b"  
    ]

    for term in remove_terms:
        x = re.sub(term, "", x)
    #fix lefover amp 038
    x=x.replace("amp 038","&")
    # Trim after removal
    x = " ".join(x.split())

    # Title-case after cleaning
    x = x.title()

    return x

company_values = []
for _, row in df.iterrows(): 
    comp = row["Company Name"]
    comp=clean_company_name(comp)
    if "Collinwood" in comp:
        print('x',comp)
    country = row["Country"]
    country_code = existing_countries.get(country)  # may be None
    country_code='US'
    company_values.append((comp, country_code))

company_insert_sql = """
    INSERT INTO dim_companies (company_name, country_code)
    VALUES %s
    ON CONFLICT (company_name) DO NOTHING
    ;
"""
execute_values(cur, company_insert_sql, company_values)
conn.commit()

# Build dictionary: company_name → company_id
cur.execute("SELECT company_id, company_name FROM dim_companies;")
company_lookup = {row[1]: row[0] for row in cur.fetchall()}
# Out:
# y collinwood technology partners
# x Collinwood Technology Partners
# y collinwood technology partners, llc
# x Collinwood Technology Partners

# %%
import csv
import re

failed_rows = []
job_rows = []
print(df.head(10))
for idx, row in df.iterrows():

    job_country = row["Country"]

    # --------------------------------------------------------
    # 1) Country Validation
    # --------------------------------------------------------
   
    if job_country not in existing_countries:
        failed_rows.append(row.to_dict())   # FIXED
        continue

    country_code = existing_countries[job_country]
    comp=row["Company Name"]
    comp=clean_company_name(comp)
    print(comp)
    comp_id = company_lookup.get(comp)
    if comp_id is None: 
        print('fail', comp)
        failed_rows.append(row.to_dict())   # FIXED
        continue

    # --------------------------------------------------------
    # 2) Build JobListingID with MIC- prefix
    # --------------------------------------------------------
    job_id = f"MIC_{idx+1:05d}"

    # --------------------------------------------------------
    # 3) Parse Salary Min and Max
    # --------------------------------------------------------
    salary_text = str(row["Salary Estimate"])  # ensure string
    numbers = re.findall(r"\d+", salary_text)

    def safe_int(x):
        try:
            return int(x) * 1000
        except:
            return None

    if len(numbers) >= 2:
        salary_min = safe_int(numbers[0])
        salary_max = safe_int(numbers[1])
    elif len(numbers) == 1:
        salary_min = safe_int(numbers[0])
        salary_max = None
    else:
        salary_min = None
        salary_max = None

    # --------------------------------------------------------
    # 4) Store Valid Job Row
    # --------------------------------------------------------
    job_rows.append((
        job_id,
        comp_id,
        row["Job Title"],
        salary_min,
        salary_max,
        row["Job Description"]
    ))

# --------------------------------------------------------
# 5) Write failed rows
# --------------------------------------------------------
if failed_rows:
    failed_file = "source_failed_country.csv"
    with open(failed_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=df.columns)
        writer.writeheader()
        writer.writerows(failed_rows)

    print(f"{len(failed_rows)} rows skipped (invalid country). Written to {failed_file}")

# --------------------------------------------------------
# 6) Insert into fact_jobs
# --------------------------------------------------------
try:
    job_insert_sql = """
        INSERT INTO fact_jobs (
            JobListingID, company_id, job_title,
            salary_min, salary_max, description
        )
        VALUES %s
        ON CONFLICT (JobListingID) DO NOTHING;
    """
    execute_values(cur, job_insert_sql, job_rows)
    conn.commit()

except Exception as e:
    print("Error inserting into fact_jobs:", e)
    conn.rollback()
# Out:
#                                            Job Title  \
# 0  Big Data Developer ( Applications Systems Engi...
# 1           Project Staff, Consultant, Data Engineer
# 2                               Senior Data Engineer
# 3  SONUS Engineer/Senior Engineer, IT Network Inf...
# 4                                 Ab Initio Engineer
# 5                             ADAS Test V&V Engineer
# 6                               Advanced AI Engineer
# 7                      Advanced Python Data Engineer
# 8      Advanced Software Engineer - Server - 20-0100
# 9  Advisory Services - Consultant: Data Engineer ...
#
#                Salary Estimate  \
# 0  $66K-$122K (Glassdoor est.)
# 1  $81K-$141K (Glassdoor est.)
# 2  $60K-$109K (Glassdoor est.)
# 3  $60K-$109K (Glassdoor est.)
# 4  $73K-$126K (Glassdoor est.)
# 5  $79K-$104K (Glassdoor est.)
# 6   $62K-$92K (Glassdoor est.)
# 7  $67K-$126K (Glassdoor est.)
# 8  $53K-$100K (Glassdoor est.)
# 9  $81K-$100K (Glassdoor est.)
#
#                                      Job Description Rating  \
# 0  Job Description Important Note: During the app...    3.6
# 1  As a team member in the Finance and Internal A...    3.6
# 2  Location: Dallas, New York, Pittsburgh Geograp...    4.3
# 3  (SONUS) Engineer/Senior Engineer, IT Network I...    3.8
# 4  Job Description Important Note: During the app...    3.6
# 5  ADAS Test V&V Engineer Description The ADAS te...    4.6
# 6  Join a team recognized for leadership, innovat...    3.8
# 7  Job Description We are looking for a savvy Dat...      4
# 8  We are Relativity. A market-leading, global te...    3.7
# 9  AddThisShare Data Engineer Avaap is a global, ...      4
#
#               Company Name        Location       Headquarters  \
# 0              Wells Fargo    Chandler, AZ  San Francisco, CA
# 1               Nationwide  Scottsdale, AZ       Columbus, OH
# 2  Boston Consulting Group      Dallas, TX         Boston, MA
# 3        American Airlines  Fort Worth, TX     Fort Worth, TX
# 4              Wells Fargo    Chandler, AZ  San Francisco, CA
# 5     Nikola Motor Company     Phoenix, AZ        Phoenix, AZ
# 6                Honeywell     Houston, TX      Charlotte, NC
# 7           Latitude, Inc.      Austin, TX        Hanover, MD
# 8               Relativity     Chicago, IL        Chicago, IL
# 9                    Avaap     Chicago, IL         Edison, NJ
#
#                      Size Founded  Type of ownership  \
# 0        10000+ employees    1852   Company - Public
# 1        10000+ employees    1925  Company - Private
# 2        10000+ employees    1963  Company - Private
# 3        10000+ employees    1926   Company - Public
# 4        10000+ employees    1852   Company - Public
# 5    201 to 500 employees    2014   Company - Public
# 6        10000+ employees    1885   Company - Public
# 7       1 to 50 employees      -1  Company - Private
# 8  1001 to 5000 employees    2001  Company - Private
# 9   501 to 1000 employees    2006  Company - Private
#
#                                   Industry                  Sector  \
# 0                    Banks & Credit Unions                 Finance
# 1                                       -1                      -1
# 2                               Consulting       Business Services
# 3                                 Airlines        Travel & Tourism
# 4                    Banks & Credit Unions                 Finance
# 5   Transportation Equipment Manufacturing           Manufacturing
# 6             Computer Hardware & Software  Information Technology
# 7                               Consulting       Business Services
# 8  Enterprise Software & Network Solutions  Information Technology
# 9                              IT Services  Information Technology
#
#                       Revenue  \
# 0          $10+ billion (USD)
# 1          $10+ billion (USD)
# 2     $5 to $10 million (USD)
# 3          $10+ billion (USD)
# 4          $10+ billion (USD)
# 5  Less than $1 million (USD)
# 6          $10+ billion (USD)
# 7      $1 to $5 million (USD)
# 8    Unknown / Non-Applicable
# 9    Unknown / Non-Applicable
#
#                                          Competitors Easy Apply Country
# 0                                                 -1         -1      US
# 1                   Allstate, Prudential, State Farm         -1      US
# 2      McKinsey & Company, Bain & Company, Accenture         -1      US
# 3  Delta Air Lines, United Airlines, Southwest Ai...         -1      US
# 4                                                 -1         -1      US
# 5                                                 -1         -1      US
# 6          GE, Johnson Controls, United Technologies         -1      US
# 7                                                 -1         -1      US
# 8                                                 -1         -1      US
# 9                                                 -1         -1      US
# Wells Fargo
# Nationwide
# Boston Consulting Group
# American Airlines
# Wells Fargo
# Nikola Motor Company
# Honeywell
# Latitude
# Relativity
# Avaap
# Leidos Holdings
# Intel
# Infotree Service
# Omnitracs
# Acs Solutions
# Samsung Research America
# Primus Global Services
# K Tek Resourcing
# Themesoft
# Cynet Systems
# Mondo
# Frontier Technology
# Lumaxia Consulting
# Bell Helicopter
# Jones Lange Lasalle
# Amazon
# Cirrus Logic
# Cirrus Logic
# Clearcover
# Health Union
# Dun Bradstreet
# Rockwell Automation
# Omnitracs
# Apple
# Listrak
# Crescent Electric Supply
# Opex Corporation
# Mufg
# Comet Group
# Cirrus Logic
# Group O
# Axiom Group
# General Dynamics
# Optumcare
# Sciplay
# Scientific Games
# Talend
# L3Harris
# Susquehanna International Group
# Applied Optoelectronics
# Neri
# Nbcp
# Bell Helicopter
# Bell Helicopter
# Textron
# Lockheed Martin
# Lpl Financial
# Itmc Systems
# Randstad
# Cynet Systems
# Xoriant Corporation
# Tek Leaders
# Resmed
# Nextxap
# Kforce
# Lorven Technologies
# Diverse Lynx
# It Trailblazers
# Tms
# System Soft Technologies
# Eninsystems
# Diverse Lynx
# Cable One
# Kforce
# Vse
# Cgi
# Cgi Technologies And Solutions
# Jnit Technologies
# Tek Leaders
# Tek Leaders
# Provish
# Diverse Lynx
# Vdart
# Diverse Lynx
# Cognizant Technology Solutions
# Microtek Digital
# Sendlane
# All Campus
# Bambee
# Clumio
# O3 World
# Affinipay
# Numerator
# Deepgram
# Learnplatform
# Deepgram
# Sensemetrics
# Clickup
# Spotify
# Nikola Motor Company
# Myticas Consulting
# Crown Castle
# Stellent It
# Eteam
# Wipro
# Jpmorgan Chase Bank N A
# Object Technology Solutions
# Object Technology Solutions
# Citi
# Citi
# Citibank
# Intraedge
# Youth Power Technosoft
# Fisher Investments
# Georgia It
# Amazon
# Resource Logistics
# Trovetechs
# Prolim Global Corporation
# Management Decisions
# Involgix
# Involgix
# Collabera
# Edgilent Corp
# Vdeploy Consulting
# Sky Consulting
# Liniumit
# Mindteck
# Robert Half
# Idc Technologies
# Intraedge
# Sysmind
# Xoriant Corporation
# Metasys Technologies
# Impetus
# Isgit
# Diverse Lynx
# Callibus
# Lorven Technologies
# Stm Consulting
# Impetus Technologies
# Intraedge
# Robert Half
# Tiger Analytics
# Softcom Systems
# Aptask
# Omega Solutions
# Pyramid Consulting
# Inseego
# Allstate
# Allstate
# Tata Consultancy Services
# Onica A Rackspace Company
# Elan Partners
# Datasys Consulting And Software
# Alt Shift Usa
# Tiger Analytics
# Ksquare Solutions
# Tata Consultancy Services North America
# Datasysamerica
# Cloudpoint Systems
# Tachyon Technologies
# Frontier Communications
# Horizontal Talent
# Enterprise Solutions
# Diverse Lynx
# Infovision
# Sliq Information Technologies
# Zacxo
# Plume
# Springml
# Zoom
# Plume
# Springml
# Nextgen Technologies
# Deloitte
# Qstride
# Cesusa
# Springml
# Springml
# Onica A Rackspace Company
# Cynet Systems
# Lorven Technologies
# Allstate
# Tata Consultancy Services
# Tata Consultancy Services North America
# Tachyon Technologies
# Node Digital
# Enterprise Solutions
# Diverse Lynx
# Centro
# Centro
# Enwidth
# Frontend Arts
# Tiger Analytics
# Tiger Analytics
# Resource Logistics
# Resource Logistics
# Allstate
# Allstate
# Allstate
# Allstate
# Intraedge
# Pyramid Consulting
# Reliable Software Resources
# Nucleusteq
# Ksquareinc
# Livemindz
# Nucleusteq
# Amgenium
# Youth Power Technosoft
# American Systems
# Apple
# Allstate Insurance 1202 Irving Tx
# Idexcel
# Jc Penney
# Intraedge
# Intraedge
